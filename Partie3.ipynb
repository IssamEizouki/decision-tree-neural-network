# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
test = pd.read_csv(io.StringIO(uploaded['y_test.csv'].decode('utf-8')))
test
# Out:
#      <input type="file" id="files-e62ac610-da30-418e-99f4-450d20668f74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e62ac610-da30-418e-99f4-450d20668f74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_test.csv to y_test.csv
#      3
# 0    1
# 1    2
# 2    0
# 3    0
# 4    1
# ..  ..
# 454  2
# 455  1
# 456  0
# 457  1
# 458  0
#
# [459 rows x 1 columns]

# %%
from google.colab import files
uploaded = files.upload()
pred1 = pd.read_csv(io.StringIO(uploaded['y_pred_NN_relu_6-4.csv'].decode('utf-8')))
pred1
# Out:
#      <input type="file" id="files-55cd6571-8b3c-443c-96d4-6a736b3363a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55cd6571-8b3c-443c-96d4-6a736b3363a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_pred_NN_relu_6-4.csv to y_pred_NN_relu_6-4.csv
#      5.052064420895164831e-01  7.636069656707789033e-02  \
# 0                    0.001335                  0.950729
# 1                    0.008622                  0.019689
# 2                    0.485732                  0.249074
# 3                    0.997876                  0.000048
# 4                    0.046699                  0.905000
# ..                        ...                       ...
# 454                  0.003147                  0.010847
# ...

# %%
from google.colab import files
uploaded = files.upload()
pred2 = pd.read_csv(io.StringIO(uploaded['y_pred_NN_relu_10-8-4.csv'].decode('utf-8')))
pred2
# Out:
#      <input type="file" id="files-e2eb044a-9ef5-49a3-89fb-97aa062d9fa3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2eb044a-9ef5-49a3-89fb-97aa062d9fa3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_pred_NN_relu_10-8-4.csv to y_pred_NN_relu_10-8-4.csv
#      7.050006826563719187e-02  2.537702026879273300e-03  \
# 0                    0.002369                  0.948276
# 1                    0.052697                  0.111570
# 2                    0.259790                  0.133129
# 3                    0.991500                  0.000289
# 4                    0.014636                  0.829528
# ..                        ...                       ...
# 454                  0.053027                  0.062634
# ...

# %%
from google.colab import files
uploaded = files.upload()
pred3 = pd.read_csv(io.StringIO(uploaded['y_pred_NN_relu_10-8-6.csv'].decode('utf-8')))
pred3
# Out:
#      <input type="file" id="files-4a6ad158-8fad-4d8c-bae7-68add73200c8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a6ad158-8fad-4d8c-bae7-68add73200c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_pred_NN_relu_10-8-6.csv to y_pred_NN_relu_10-8-6.csv
#      3.496987285549739144e-01  4.723224505424134662e-03  \
# 0                    0.006339                  0.979699
# 1                    0.003142                  0.048495
# 2                    0.700325                  0.066004
# 3                    0.968477                  0.000107
# 4                    0.106144                  0.891400
# ..                        ...                       ...
# 454                  0.000284                  0.005046
# ...

# %%
from google.colab import files
uploaded = files.upload()
pred4 = pd.read_csv(io.StringIO(uploaded['y_pred_NN_tanh_6-4.csv'].decode('utf-8')))
pred4
# Out:
#      <input type="file" id="files-bda9d987-5c29-4482-b36f-30692fc2b952" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bda9d987-5c29-4482-b36f-30692fc2b952">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_pred_NN_tanh_6-4.csv to y_pred_NN_tanh_6-4.csv
#      6.449295347310219917e-01  1.418369180405077866e-03  \
# 0                    0.024387                  0.932928
# 1                    0.008883                  0.173266
# 2                    0.658979                  0.025912
# 3                    0.867160                  0.022206
# 4                    0.052035                  0.830923
# ..                        ...                       ...
# 454                  0.007617                  0.233617
# ...

# %%
from google.colab import files
uploaded = files.upload()
pred5 = pd.read_csv(io.StringIO(uploaded['y_pred_NN_tanh_10-8-4.csv'].decode('utf-8')))
pred5
# Out:
#      <input type="file" id="files-78a29084-a624-4f7e-a001-4a6167bd39ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78a29084-a624-4f7e-a001-4a6167bd39ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_pred_NN_tanh_10-8-4.csv to y_pred_NN_tanh_10-8-4.csv
#      3.158609282210180225e-01  1.349126702602631775e-02  \
# 0                    0.013333                  0.942865
# 1                    0.028500                  0.127926
# 2                    0.371006                  0.049233
# 3                    0.878656                  0.011335
# 4                    0.041102                  0.883222
# ..                        ...                       ...
# 454                  0.034616                  0.082131
# ...

# %%
from google.colab import files
uploaded = files.upload()
pred6 = pd.read_csv(io.StringIO(uploaded['y_pred_NN_tanh_10-8-6.csv'].decode('utf-8')))
pred6
# Out:
#      <input type="file" id="files-a33ce3e6-54a5-4866-916a-e05798559570" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a33ce3e6-54a5-4866-916a-e05798559570">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_pred_NN_tanh_10-8-6.csv to y_pred_NN_tanh_10-8-6.csv
#      8.237605422306408520e-02  3.614134161986007343e-02  \
# 0                    0.008121                  0.981520
# 1                    0.018651                  0.085604
# 2                    0.643103                  0.040967
# 3                    0.963560                  0.005073
# 4                    0.028989                  0.931208
# ..                        ...                       ...
# 454                  0.016338                  0.074179
# ...

# %%
from google.colab import files
uploaded = files.upload()
pred7 = pd.read_csv(io.StringIO(uploaded['y_pred_DT4.csv'].decode('utf-8')))
pred7
# Out:
#      <input type="file" id="files-7e0e8855-f1f2-4251-89bd-f1905919706d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e0e8855-f1f2-4251-89bd-f1905919706d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_pred_DT4.csv to y_pred_DT4.csv
#      2
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# ..  ..
# 454  0
# 455  1
# 456  0
# 457  0
# 458  0
#
# [459 rows x 1 columns]

# %%
from google.colab import files
uploaded = files.upload()
pred8 = pd.read_csv(io.StringIO(uploaded['y_pred_DT5.csv'].decode('utf-8')))
pred8
# Out:
#      <input type="file" id="files-0d06d5ac-0021-49d8-bca6-b033253c5fa9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d06d5ac-0021-49d8-bca6-b033253c5fa9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_pred_DT5.csv to y_pred_DT5.csv
#      2
# 0    1
# 1    2
# 2    3
# 3    0
# 4    0
# ..  ..
# 454  2
# 455  1
# 456  0
# 457  1
# 458  0
#
# [459 rows x 1 columns]

# %%
from google.colab import files
uploaded = files.upload()
pred9 = pd.read_csv(io.StringIO(uploaded['y_pred_DT6.csv'].decode('utf-8')))
pred9
# Out:
#      <input type="file" id="files-0acf523b-a8e0-4c5e-94c6-3d4bca7272fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0acf523b-a8e0-4c5e-94c6-3d4bca7272fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y_pred_DT6.csv to y_pred_DT6.csv
#      3
# 0    1
# 1    2
# 2    3
# 3    0
# 4    0
# ..  ..
# 454  2
# 455  1
# 456  0
# 457  1
# 458  0
#
# [459 rows x 1 columns]

# %%
def norm(p):
  pred = p
  cols=pred.columns.tolist()
  max=0
  for i in range(pred.shape[0]):
    max=pred[cols[0]][i]
    pred[cols[0]][i] = 1
    indice = 0
    for e in range(1,len(cols)):
      if(pred[cols[e]][i] > max):
        max = pred[cols[e]][i]
        pred[cols[indice]][i] = 0
        indice = e
        pred[cols[e]][i] = 1
      else:
        pred[cols[e]][i] = 0
  return pred

# %%
def determination_classe(i0,i1,i2,i3):
  if i0 == 1:
    return 0
  elif i1 == 1:
    return 1
  elif i2 == 1:
    return 2
  elif i3 == 1:
    return 3

# %%
def TP(test,pred,classe):
  counter = 0
  for i in range(test.shape[0]):
    if test["3"][i] == classe and test["3"][i] == pred["2"][i]:
      counter += 1
  return counter

# %%
def TP_NN(test,pred,classe):
  counter = 0
  cols = pred.columns.tolist()
  for i in range(test.shape[0]):
    c = determination_classe(pred[cols[0]][i],pred[cols[1]][i],pred[cols[2]][i],pred[cols[3]][i])
    if test["3"][i] == classe and c == classe:
      counter += 1
  return counter

# %%
def TN(test,pred,classe):
  counter = 0
  for i in range(test.shape[0]):
    if test["3"][i] != classe and pred["2"][i]!=classe:
      counter += 1
  return counter

# %%
def TN_NN(test,pred,classe):
  counter = 0
  cols = pred.columns.tolist()
  for i in range(test.shape[0]):
    c = determination_classe(pred[cols[0]][i],pred[cols[1]][i],pred[cols[2]][i],pred[cols[3]][i])
    if test["3"][i] != classe and c!=classe:
      counter += 1
  return counter

# %%
def FP(test,pred,classe):
  counter = 0
  for i in range(test.shape[0]):
    if test["3"][i] != classe and pred["2"][i]==classe:
      counter += 1
  return counter

# %%
def FP_NN(test,pred,classe):
  counter = 0
  cols = pred.columns.tolist()
  for i in range(test.shape[0]):
    c = determination_classe(pred[cols[0]][i],pred[cols[1]][i],pred[cols[2]][i],pred[cols[3]][i])
    if test["3"][i] != classe and c == classe:
      counter += 1
  return counter

# %%
def FN(test,pred,classe):
  counter = 0
  for i in range(test.shape[0]):
    if test["3"][i] == classe and pred["2"][i]!=classe:
      counter += 1
  return counter

# %%
def FN_NN(test,pred,classe):
  counter = 0
  cols = pred.columns.tolist()
  for i in range(test.shape[0]):
    c = determination_classe(pred[cols[0]][i],pred[cols[1]][i],pred[cols[2]][i],pred[cols[3]][i])
    if test["3"][i] == classe and c != classe:
      counter += 1
  return counter

# %%
def precision(test,pred,classe):
  if(len(pred.columns.tolist())>1):
    tp = TP_NN(test,pred,classe)
    fp = FP_NN(test,pred,classe)
  else:
    tp = TP(test,pred,classe)
    fp = FP(test,pred,classe)
  if(tp+fp>0):
    return tp / (tp+fp)
  else:
    return 0

# %%
def recall(test,pred,classe):
  if(len(pred.columns.tolist())>1):
    tp = TP_NN(test,pred,classe)
    fn = FN_NN(test,pred,classe)
  else:
    tp = TP(test,pred,classe)
    fn = FN(test,pred,classe)
  if(tp+fn>0):
    return tp / (tp+fn)
  else:
    return 0

# %%
def F1_score(test,pred,classe):
  r = recall(test,pred,classe)
  p = precision(test,pred,classe)
  if(p+r)>0:
    return 2 * (p * r) / (p + r)
  else:
    return 0

# %%
def exactitude(test,pred,classe):
  if(len(pred.columns.tolist())>1):
    tp = TP_NN(test,pred,classe)
    tn = TN_NN(test,pred,classe)
  else:
    tp = TP(test,pred,classe)
    tn = TN(test,pred,classe)
  return (tp+tn) / test.shape[0]

# %%
def aPredib(test,pred,a,b):
  counter = 0
  if(len(pred.columns.tolist())>1):
    cols = pred.columns.tolist()
    for i in range(test.shape[0]):
      c = determination_classe(pred[cols[0]][i],pred[cols[1]][i],pred[cols[2]][i],pred[cols[3]][i])
      if test["3"][i] == a and c == b:
        counter += 1
  else:
    for i in range(test.shape[0]):
      if test["3"][i] == a and pred["2"][i]==b:
        counter += 1
  return counter

# %%
#Comparaison des modèle , ce block nécéssite etre executer apres le block de récupération des predictions qui doivent être importer de la me manière que dans ce programme (pred1,...,pred9)

#normalisation 
norm(pred1)
norm(pred2)
norm(pred3)
norm(pred4)
norm(pred5)
norm(pred6)


pred9.columns = ['2']
pred9 

print("Precision:")
print("y_pred_NN_relu_6-4.csv:")
print(precision(test,pred1,0))
print(precision(test,pred1,1))
print(precision(test,pred1,2))
print(precision(test,pred1,3))
print("\n")

print("y_pred_NN_relu_10-8-4.csv:")
print(precision(test,pred2,0))
print(precision(test,pred2,1))
print(precision(test,pred2,2))
print(precision(test,pred2,3))
print("\n")

print("y_pred_NN_relu_10-8-6.csv:")
print(precision(test,pred3,0))
print(precision(test,pred3,1))
print(precision(test,pred3,2))
print(precision(test,pred3,3))
print("\n")

print("y_pred_NN_tanh_6-4.csv:")
print(precision(test,pred4,0))
print(precision(test,pred4,1))
print(precision(test,pred4,2))
print(precision(test,pred4,3))
print("\n")


print("y_pred_NN_tanh_10-8-4.csv:")
print(precision(test,pred5,0))
print(precision(test,pred5,1))
print(precision(test,pred5,2))
print(precision(test,pred5,3))
print("\n")

print("y_pred_NN_tanh_10-8-6.csv:")
print(precision(test,pred6,0))
print(precision(test,pred6,1))
print(precision(test,pred6,2))
print(precision(test,pred6,3))
print("\n")

print("y_pred_DT4.csv:")
print(precision(test,pred7,0))
print(precision(test,pred7,1))
print(precision(test,pred7,2))
print(precision(test,pred7,3))
print("\n")

print("y_pred_DT5.csv:")
print(precision(test,pred8,0))
print(precision(test,pred8,1))
print(precision(test,pred8,2))
print(precision(test,pred8,3))
print("\n")

print("y_pred_DT6.csv:")
print(precision(test,pred9,0))
print(precision(test,pred9,1))
print(precision(test,pred9,2))
print(precision(test,pred9,3))

print("\n\n")



print("Recall:")
print("y_pred_NN_relu_6-4.csv:")
print(recall(test,pred1,0))
print(recall(test,pred1,1))
print(recall(test,pred1,2))
print(recall(test,pred1,3))
print("\n")

print("y_pred_NN_relu_10-8-4.csv:")
print(recall(test,pred2,0))
print(recall(test,pred2,1))
print(recall(test,pred2,2))
print(recall(test,pred2,3))
print("\n")

print("y_pred_NN_relu_10-8-6.csv:")
print(recall(test,pred3,0))
print(recall(test,pred3,1))
print(recall(test,pred3,2))
print(recall(test,pred3,3))
print("\n")

print("y_pred_NN_tanh_6-4.csv:")
print(recall(test,pred4,0))
print(recall(test,pred4,1))
print(recall(test,pred4,2))
print(recall(test,pred4,3))
print("\n")

print("y_pred_NN_tanh_10-8-4.csv:")
print(recall(test,pred5,0))
print(recall(test,pred5,1))
print(recall(test,pred5,2))
print(recall(test,pred5,3))
print("\n")

print("y_pred_NN_tanh_10-8-6.csv:")
print(recall(test,pred6,0))
print(recall(test,pred6,1))
print(recall(test,pred6,2))
print(recall(test,pred6,3))
print("\n")

print("y_pred_DT4.csv:")
print(recall(test,pred7,0))
print(recall(test,pred7,1))
print(recall(test,pred7,2))
print(recall(test,pred7,3))
print("\n")

print("y_pred_DT5.csv:")
print(recall(test,pred8,0))
print(recall(test,pred8,1))
print(recall(test,pred8,2))
print(recall(test,pred8,3))
print("\n")

print("y_pred_DT6.csv:")
print(recall(test,pred9,0))
print(recall(test,pred9,1))
print(recall(test,pred9,2))
print(recall(test,pred9,3))



print("\n\n")

print("F1-score:")
print("y_pred_NN_relu_6-4.csv:")
print(F1_score(test,pred1,0))
print(F1_score(test,pred1,1))
print(F1_score(test,pred1,2))
print(F1_score(test,pred1,3))
print("\n")

print("y_pred_NN_relu_10-8-4.csv:")
print(F1_score(test,pred2,0))
print(F1_score(test,pred2,1))
print(F1_score(test,pred2,2))
print(F1_score(test,pred2,3))
print("\n")

print("y_pred_NN_relu_10-8-6.csv:")
print(F1_score(test,pred3,0))
print(F1_score(test,pred3,1))
print(F1_score(test,pred3,2))
print(F1_score(test,pred3,3))
print("\n")

print("y_pred_NN_tanh_6-4.csv:")
print(F1_score(test,pred4,0))
print(F1_score(test,pred4,1))
print(F1_score(test,pred4,2))
print(F1_score(test,pred4,3))
print("\n")

print("y_pred_NN_tanh_10-8-4.csv:")
print(F1_score(test,pred5,0))
print(F1_score(test,pred5,1))
print(F1_score(test,pred5,2))
print(F1_score(test,pred5,3))
print("\n")

print("y_pred_NN_tanh_10-8-6.csv:")
print(F1_score(test,pred6,0))
print(F1_score(test,pred6,1))
print(F1_score(test,pred6,2))
print(F1_score(test,pred6,3))
print("\n")



print("\n\n")

print("exactitude:")
print("y_pred_NN_relu_6-4.csv:")
print(exactitude(test,pred1,0))
print(exactitude(test,pred1,1))
print(exactitude(test,pred1,2))
print(exactitude(test,pred1,3))
print("\n")

print("y_pred_NN_relu_10-8-4.csv:")
print(exactitude(test,pred2,0))
print(exactitude(test,pred2,1))
print(exactitude(test,pred2,2))
print(exactitude(test,pred2,3))
print("\n")

print("y_pred_NN_relu_10-8-6.csv:")
print(exactitude(test,pred3,0))
print(exactitude(test,pred3,1))
print(exactitude(test,pred3,2))
print(exactitude(test,pred3,3))
print("\n")

print("y_pred_NN_tanh_6-4.csv:")
print(exactitude(test,pred4,0))
print(exactitude(test,pred4,1))
print(exactitude(test,pred4,2))
print(exactitude(test,pred4,3))
print("\n")

print("y_pred_NN_tanh_10-8-4.csv:")
print(exactitude(test,pred5,0))
print(exactitude(test,pred5,1))
print(exactitude(test,pred5,2))
print(exactitude(test,pred5,3))
print("\n")

print("y_pred_NN_tanh_10-8-6.csv:")
print(exactitude(test,pred6,0))
print(exactitude(test,pred6,1))
print(exactitude(test,pred6,2))
print(exactitude(test,pred6,3))
print("\n")

print("y_pred_DT4.csv:")
print(exactitude(test,pred7,0))
print(exactitude(test,pred7,1))
print(exactitude(test,pred7,2))
print(exactitude(test,pred7,3))
print("\n")

print("y_pred_DT5.csv:")
print(exactitude(test,pred8,0))
print(exactitude(test,pred8,1))
print(exactitude(test,pred8,2))
print(exactitude(test,pred8,3))
print("\n")

print("y_pred_DT6.csv:")
print(exactitude(test,pred9,0))
print(exactitude(test,pred9,1))
print(exactitude(test,pred9,2))
print(exactitude(test,pred9,3))
# Out:
# Precision:
# y_pred_NN_relu_6-4.csv:
# 0.9379310344827586
# 0.9075144508670521
# 0.7884615384615384
# 0.6486486486486487
#
#
# y_pred_NN_relu_10-8-4.csv:
# 0.9714285714285714
# 0.8716577540106952
# 0.8350515463917526
# 0.7142857142857143
#
#
# y_pred_NN_relu_10-8-6.csv:
# 0.9712230215827338
# 0.9011627906976745
# 0.8080808080808081
# 0.6326530612244898
#
#
# y_pred_NN_tanh_6-4.csv:
# 0.8475609756097561
# 0.868421052631579
# 0.7523809523809524
# 0
#
#
# y_pred_NN_tanh_10-8-4.csv:
# 0.9044585987261147
# 0.8670212765957447
# 0.7368421052631579
# 0
#
#
# y_pred_NN_tanh_10-8-6.csv:
# 0.9664429530201343
# 0.8950276243093923
# 0.9101123595505618
# 0.775
#
#
# y_pred_DT4.csv:
# 0.7142857142857143
# 0.7577319587628866
# 0.5945945945945946
# 0.6666666666666666
#
#
# y_pred_DT5.csv:
# 0.802547770700637
# 0.8536585365853658
# 0.6633663366336634
# 0.5675675675675675
#
#
# y_pred_DT6.csv:
# 0.8496732026143791
# 0.84
# 0.7473684210526316
# 0.6944444444444444
#
#
#
# Recall:
# ...

# %%
def matrice_confusion(test,pred):
  res = [[],[],[],[]]
  for i in range(4):
    for j in range(4):
      res[i].append(aPredib(test,pred,i,j))
  return res

m = matrice_confusion(test,pred1)
for i in range(4):
  print(m[i])
# Out:
# [136, 6, 5, 9]
# [3, 157, 5, 1]
# [2, 2, 82, 3]
# [4, 8, 12, 24]

# %%
def classification_report(test,pred):
  res = [[],[],[],[]]
  for i in range(4):
    res[0].append(exactitude(test,pred,i))
    res[1].append(precision(test,pred,i))
    res[2].append(recall(test,pred,i))
    res[3].append(F1_score(test,pred,i))
  return res

m = classification_report(test,pred)
for i in range(4):
  print(m[i])
# Out:
# [0.9368191721132898, 0.9455337690631809, 0.9368191721132898, 0.9193899782135077]
# [0.9379310344827586, 0.9075144508670521, 0.7884615384615384, 0.6486486486486487]
# [0.8717948717948718, 0.9457831325301205, 0.9213483146067416, 0.5]
# [0.9036544850498339, 0.9262536873156342, 0.8497409326424871, 0.5647058823529412]
